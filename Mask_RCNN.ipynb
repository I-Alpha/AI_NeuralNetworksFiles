# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content
# !mkdir images
# !mkdir data
# %cd /content/data
# !mkdir images
# !mkdir masks
# !tar -xf "/content/drive/My Drive/My Files/Project 2019 Data/images.tar"  -C /content/images
# %cd /content
# %cd /content/data/images
# !mkdir train
# !mkdir test

# %cd /content/data/masks
# !mkdir train
# !mkdir test

# %cd /content/data/masks/train
# !mkdir Lateral
# !mkdir Primary
# !mkdir Seeds
# !mkdir Segmentation

# !cp -r /content/images/images/{0000..2675}.png /content/data/images/train
# !cp -r /content/images/lateral16/{0000..2675}.png /content/data/masks/train/Lateral
# !cp -r /content/images/primary16/{0000..2675}.png /content/data/masks/train/Primary
# !cp -r /content/images/seeds/{0000..2675}.png /content/data/masks/train/Seeds
# !cp -r /content/images/segmentation8/{0000..2675}.png /content/data/masks/train/Segmentation

# %%
# !git clone https://github.com/I-Alpha/Mask_RCNN.git
# Out:
# Cloning into 'Mask_RCNN'...
# remote: Enumerating objects: 956, done.
# remote: Total 956 (delta 0), reused 0 (delta 0), pack-reused 956
# Receiving objects: 100% (956/956), 111.90 MiB | 51.92 MiB/s, done.
# Resolving deltas: 100% (571/571), done.
